# %%
# !pip install sympy
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# !jupyter labextension install jupyter-matplotlib
# Out:
# ...
# Building jupyterlab assets (build:prod:minimize)
# Building jupyterlab assets (build:prod:minimize)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
def plot_graph(X,Y,p,u,v):
    fig = pyplot.figure(figsize=(11,7), dpi=100)
    # plotting the pressure field as a contour
    pyplot.contourf(X, Y, p, alpha=0.5, cmap=cm.viridis)  
    pyplot.colorbar()
    # plotting the pressure field outlines
    pyplot.contour(X, Y, p, cmap=cm.viridis)  
    # plotting velocity field
    pyplot.quiver(X[::2, ::2], Y[::2, ::2], u[::2, ::2], v[::2, ::2]) 
    pyplot.xlabel('X')
    pyplot.ylabel('Y');

# %%
def construct_matrices_from_file_and_plot(filename):
    data = pd.read_csv(filename, header=None) 
    x = numpy.linspace(0, 2, 41)
    y = numpy.linspace(0, 2, 41)
    X, Y = numpy.meshgrid(x, y)
    p = data.values[1:42].astype(float)
    u = data.values[43:84].astype(float)
    v = data.values[85:126].astype(float)
    plot_graph(X,Y,p,u,v)

# %% [markdown]
# # Testing c++ code result:

# %% [markdown]
# For nt = 100

# %%
construct_matrices_from_file_and_plot("results_cav_nt100.csv")

# %% [markdown]
# For nt = 700

# %%
construct_matrices_from_file_and_plot("results_cav_nt700.csv")

# %% [markdown]
# # Testing CUDA c++ code result:

# %% [markdown]
# For nt = 100

# %%
construct_matrices_from_file_and_plot("results_nt100.csv")

# %% [markdown]
# nt = 700

# %%
construct_matrices_from_file_and_plot("results_nt700.csv")
